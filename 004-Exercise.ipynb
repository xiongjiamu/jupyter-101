# %% [markdown]
# ## Exercise 1 Note
#
# #### `Ctrl-Enter` `Shift-Enter` & `Alt-Enter`
#
# - `Ctrl-Enter` ，执行/重复执行当前 cell
# - `Shift-Enter`，执行当前 cell 并跳转至下一个 cell（没有的话则新建一个 cell）
# - `Alt-Enter`，执行当前 cell 并新建一个 cell

# %% [markdown]
# #### Import
#
# 在`代码 cell` 中，可以通过 `pip install xxx` & `import xxx` 的方式来导入非标准库（即不是系统自带的 lib）
#
# 导入完成后，在`代码 cell` 中你依旧可以像 IDE 那样 使用 `tab` 键来获得补全提示，补全信息的种类包括：
#
# ```html
# m (红色) `#d9282c` -- module
# f (蓝色）`#1577b2` -- function
# c（绿色）`#21a037` -- class
# i （橙色）`#ff7f24` -- instance
# ```
#
# 同时你可以开启上下文帮助（`command + I`），查看具体某个方法的使用提示
#
# 非常的方便。

# %% [markdown]
# ## Exercise 2 Note
#
# #### Input/Output 收起
#
# Input / Output 在内容过长不便于阅读的时候，可以选择以下两种方式来进行处理，分别是：
#
# - 隐藏，可以单击 Input / Output 左侧的颜色条，来隐藏/显示 内容；
# - 滚动输出，可以在 Input / Output 上单击右键，然后选择 `启用滚动输出` 来固定内容展示高度，并启用滚动条；

# %% [markdown]
# #### 新建 Console
#
# 从文件中新建 console 的时候（包括 .ipynb文件、markdown 文件），除了新建 console 外，还可以将是使用已经启动了的 console，并直接将文件中的代码内容在已经启动过的 console 中直接运行，并重复利用之前导入过的 lib、定义过的变量、 function 等。

# %% [markdown]
# #### 更改内核
#
# 对于每个 .ipynb A 文件，都可以选择更改它的内核，甚至可以将另外一个打开的 .ipynb B 文件作为它的内核来使用，让 A 从 B 上继承参数等内容。

# %% [markdown]
# ## Exercise 3 Note
#
# ### 关于用户配置
#
# Tips：
#
# 1. 不需要将 markdown 文件中的代码复制到 console 中去运行（ .ipynb 中的代码可以直接运行，更加不需要考虑复制到 console 中去执行），只需要为 markdown 文件新建 console，并选中要执行的代码/代码块，然后通过 `Shift + Enter` 命令运行即可；
# 2. JupyterLab 针对不同编辑器使用习惯的用户提供了4套不同的快捷键映射方案，分别是 `default`, `Sublime Text`, `vim`, `emacs`；
# 3. JupyterLab 的相关设置（比如 layout）都存储在本地，因此刷新等操作不会影响这些设置（但是 JupyterHub 是如何运作的，这个还需要 @海峰 到时候深入了解一下）

# %% [markdown]
# ## Exercise 4 Note
#
# ### 关于右键菜单
#
# 在 cell 中 默认提供的右键菜单是基于 JupyterLab 的，但是可以通过 `Shift + 右键` 的方式来打开浏览器的右键菜单：
#
# - `右键` ：JupyterLab 菜单
# - `Shift + 右键`：浏览器菜单

# %% [markdown]
# ### JupyterLab Package.json File
#
# ```json
# {
#   "name": "@jupyterlab/application-top",
#   "version": "3.1.0-rc.1",
#   "private": true,
#   "license": "BSD-3-Clause",
#   "scripts": {
#     "build": "npm run clean && webpack",
#     "build:dev": "npm run build",
#     "build:prod": "webpack --config webpack.prod.config.js",
#     "build:prod:minimize": "webpack --config webpack.prod.minimize.config.js",
#     "build:prod:release": "webpack --config webpack.prod.release.config.js",
#     "build:prod:stats": "webpack --profile --config webpack.prod.minimize.config.js --json > stats.json",
#     "build:stats": "webpack --profile --json > stats.json",
#     "clean": "rimraf build",
#     "prepublishOnly": "npm run build",
#     "watch": "webpack --watch"
#   },
#   "resolutions": {
#     "@jupyterlab/application": "~3.1.0-rc.1",
#     "@jupyterlab/application-extension": "~3.1.0-rc.1",
#     "@jupyterlab/apputils": "~3.1.0-rc.1",
#     "@jupyterlab/apputils-extension": "~3.1.0-rc.1",
#     "@jupyterlab/attachments": "~3.1.0-rc.1",
#     "@jupyterlab/cells": "~3.1.0-rc.1",
#     "@jupyterlab/celltags": "~3.1.0-rc.1",
#     "@jupyterlab/celltags-extension": "~3.1.0-rc.1",
#     "@jupyterlab/codeeditor": "~3.1.0-rc.1",
#     "@jupyterlab/codemirror": "~3.1.0-rc.1",
#     "@jupyterlab/codemirror-extension": "~3.1.0-rc.1",
#     "@jupyterlab/completer": "~3.1.0-rc.1",
#     "@jupyterlab/completer-extension": "~3.1.0-rc.1",
#     "@jupyterlab/console": "~3.1.0-rc.1",
#     "@jupyterlab/console-extension": "~3.1.0-rc.1",
#     "@jupyterlab/coreutils": "~5.1.0-rc.1",
#     "@jupyterlab/csvviewer": "~3.1.0-rc.1",
#     "@jupyterlab/csvviewer-extension": "~3.1.0-rc.1",
#     "@jupyterlab/debugger": "~3.1.0-rc.1",
#     "@jupyterlab/debugger-extension": "~3.1.0-rc.1",
#     "@jupyterlab/docmanager": "~3.1.0-rc.1",
#     "@jupyterlab/docmanager-extension": "~3.1.0-rc.1",
#     "@jupyterlab/docprovider": "~3.1.0-rc.1",
#     "@jupyterlab/docprovider-extension": "~3.1.0-rc.1",
#     "@jupyterlab/docregistry": "~3.1.0-rc.1",
#     "@jupyterlab/documentsearch": "~3.1.0-rc.1",
#     "@jupyterlab/documentsearch-extension": "~3.1.0-rc.1",
#     "@jupyterlab/extensionmanager": "~3.1.0-rc.1",
#     "@jupyterlab/extensionmanager-extension": "~3.1.0-rc.1",
#     "@jupyterlab/filebrowser": "~3.1.0-rc.1",
#     "@jupyterlab/filebrowser-extension": "~3.1.0-rc.1",
#     "@jupyterlab/fileeditor": "~3.1.0-rc.1",
#     "@jupyterlab/fileeditor-extension": "~3.1.0-rc.1",
#     "@jupyterlab/help-extension": "~3.1.0-rc.1",
#     "@jupyterlab/htmlviewer": "~3.1.0-rc.1",
#     "@jupyterlab/htmlviewer-extension": "~3.1.0-rc.1",
#     "@jupyterlab/hub-extension": "~3.1.0-rc.1",
#     "@jupyterlab/imageviewer": "~3.1.0-rc.1",
#     "@jupyterlab/imageviewer-extension": "~3.1.0-rc.1",
#     "@jupyterlab/inspector": "~3.1.0-rc.1",
#     "@jupyterlab/inspector-extension": "~3.1.0-rc.1",
#     "@jupyterlab/javascript-extension": "~3.1.0-rc.1",
#     "@jupyterlab/json-extension": "~3.1.0-rc.1",
#     "@jupyterlab/launcher": "~3.1.0-rc.1",
#     "@jupyterlab/launcher-extension": "~3.1.0-rc.1",
#     "@jupyterlab/logconsole": "~3.1.0-rc.1",
#     "@jupyterlab/logconsole-extension": "~3.1.0-rc.1",
#     "@jupyterlab/mainmenu": "~3.1.0-rc.1",
#     "@jupyterlab/mainmenu-extension": "~3.1.0-rc.1",
#     "@jupyterlab/markdownviewer": "~3.1.0-rc.1",
#     "@jupyterlab/markdownviewer-extension": "~3.1.0-rc.1",
#     "@jupyterlab/mathjax2": "~3.1.0-rc.1",
#     "@jupyterlab/mathjax2-extension": "~3.1.0-rc.1",
#     "@jupyterlab/metapackage": "~3.1.0-rc.1",
#     "@jupyterlab/nbconvert-css": "~3.1.0-rc.1",
#     "@jupyterlab/nbformat": "~3.1.0-rc.1",
#     "@jupyterlab/notebook": "~3.1.0-rc.1",
#     "@jupyterlab/notebook-extension": "~3.1.0-rc.1",
#     "@jupyterlab/observables": "~4.1.0-rc.1",
#     "@jupyterlab/outputarea": "~3.1.0-rc.1",
#     "@jupyterlab/pdf-extension": "~3.1.0-rc.1",
#     "@jupyterlab/property-inspector": "~3.1.0-rc.1",
#     "@jupyterlab/rendermime": "~3.1.0-rc.1",
#     "@jupyterlab/rendermime-extension": "~3.1.0-rc.1",
#     "@jupyterlab/rendermime-interfaces": "~3.1.0-rc.1",
#     "@jupyterlab/running": "~3.1.0-rc.1",
#     "@jupyterlab/running-extension": "~3.1.0-rc.1",
#     "@jupyterlab/services": "~6.1.0-rc.1",
#     "@jupyterlab/settingeditor": "~3.1.0-rc.1",
#     "@jupyterlab/settingeditor-extension": "~3.1.0-rc.1",
#     "@jupyterlab/settingregistry": "~3.1.0-rc.1",
#     "@jupyterlab/shared-models": "~3.1.0-rc.1",
#     "@jupyterlab/shortcuts-extension": "~3.1.0-rc.1",
#     "@jupyterlab/statedb": "~3.1.0-rc.1",
#     "@jupyterlab/statusbar": "~3.1.0-rc.1",
#     "@jupyterlab/statusbar-extension": "~3.1.0-rc.1",
#     "@jupyterlab/terminal": "~3.1.0-rc.1",
#     "@jupyterlab/terminal-extension": "~3.1.0-rc.1",
#     "@jupyterlab/theme-dark-extension": "~3.1.0-rc.1",
#     "@jupyterlab/theme-light-extension": "~3.1.0-rc.1",
#     "@jupyterlab/toc": "~5.1.0-rc.1",
#     "@jupyterlab/toc-extension": "~5.1.0-rc.1",
#     "@jupyterlab/tooltip": "~3.1.0-rc.1",
#     "@jupyterlab/tooltip-extension": "~3.1.0-rc.1",
#     "@jupyterlab/translation": "~3.1.0-rc.1",
#     "@jupyterlab/translation-extension": "~3.1.0-rc.1",
#     "@jupyterlab/ui-components": "~3.1.0-rc.1",
#     "@jupyterlab/ui-components-extension": "~3.1.0-rc.1",
#     "@jupyterlab/vdom": "~3.1.0-rc.1",
#     "@jupyterlab/vdom-extension": "~3.1.0-rc.1",
#     "@jupyterlab/vega5-extension": "~3.1.0-rc.1",
#     "@lumino/algorithm": "^1.3.3",
#     "@lumino/application": "^1.16.0",
#     "@lumino/commands": "^1.12.0",
#     "@lumino/coreutils": "^1.5.3",
#     "@lumino/disposable": "^1.4.3",
#     "@lumino/domutils": "^1.2.3",
#     "@lumino/dragdrop": "^1.7.1",
#     "@lumino/messaging": "^1.4.3",
#     "@lumino/properties": "^1.2.3",
#     "@lumino/signaling": "^1.4.3",
#     "@lumino/virtualdom": "^1.8.0",
#     "@lumino/widgets": "^1.19.0",
#     "react": "^17.0.1",
#     "react-dom": "^17.0.1",
#     "yjs": "^13.5.6"
#   },
#   "dependencies": {
#     "@jupyterlab/application": "~3.1.0-rc.1",
#     "@jupyterlab/application-extension": "~3.1.0-rc.1",
#     "@jupyterlab/apputils-extension": "~3.1.0-rc.1",
#     "@jupyterlab/celltags-extension": "~3.1.0-rc.1",
#     "@jupyterlab/codemirror-extension": "~3.1.0-rc.1",
#     "@jupyterlab/completer-extension": "~3.1.0-rc.1",
#     "@jupyterlab/console-extension": "~3.1.0-rc.1",
#     "@jupyterlab/coreutils": "~5.1.0-rc.1",
#     "@jupyterlab/csvviewer-extension": "~3.1.0-rc.1",
#     "@jupyterlab/debugger-extension": "~3.1.0-rc.1",
#     "@jupyterlab/docmanager-extension": "~3.1.0-rc.1",
#     "@jupyterlab/docprovider-extension": "~3.1.0-rc.1",
#     "@jupyterlab/documentsearch-extension": "~3.1.0-rc.1",
#     "@jupyterlab/extensionmanager-extension": "~3.1.0-rc.1",
#     "@jupyterlab/filebrowser-extension": "~3.1.0-rc.1",
#     "@jupyterlab/fileeditor-extension": "~3.1.0-rc.1",
#     "@jupyterlab/help-extension": "~3.1.0-rc.1",
#     "@jupyterlab/htmlviewer-extension": "~3.1.0-rc.1",
#     "@jupyterlab/hub-extension": "~3.1.0-rc.1",
#     "@jupyterlab/imageviewer-extension": "~3.1.0-rc.1",
#     "@jupyterlab/inspector-extension": "~3.1.0-rc.1",
#     "@jupyterlab/javascript-extension": "~3.1.0-rc.1",
#     "@jupyterlab/json-extension": "~3.1.0-rc.1",
#     "@jupyterlab/launcher-extension": "~3.1.0-rc.1",
#     "@jupyterlab/logconsole-extension": "~3.1.0-rc.1",
#     "@jupyterlab/mainmenu-extension": "~3.1.0-rc.1",
#     "@jupyterlab/markdownviewer-extension": "~3.1.0-rc.1",
#     "@jupyterlab/mathjax2-extension": "~3.1.0-rc.1",
#     "@jupyterlab/notebook-extension": "~3.1.0-rc.1",
#     "@jupyterlab/pdf-extension": "~3.1.0-rc.1",
#     "@jupyterlab/rendermime-extension": "~3.1.0-rc.1",
#     "@jupyterlab/running-extension": "~3.1.0-rc.1",
#     "@jupyterlab/settingeditor-extension": "~3.1.0-rc.1",
#     "@jupyterlab/shortcuts-extension": "~3.1.0-rc.1",
#     "@jupyterlab/statusbar-extension": "~3.1.0-rc.1",
#     "@jupyterlab/terminal-extension": "~3.1.0-rc.1",
#     "@jupyterlab/theme-dark-extension": "~3.1.0-rc.1",
#     "@jupyterlab/theme-light-extension": "~3.1.0-rc.1",
#     "@jupyterlab/toc-extension": "~5.1.0-rc.1",
#     "@jupyterlab/tooltip-extension": "~3.1.0-rc.1",
#     "@jupyterlab/translation-extension": "~3.1.0-rc.1",
#     "@jupyterlab/ui-components-extension": "~3.1.0-rc.1",
#     "@jupyterlab/vdom-extension": "~3.1.0-rc.1",
#     "@jupyterlab/vega5-extension": "~3.1.0-rc.1"
#   },
#   "devDependencies": {
#     "@jupyterlab/builder": "^3.1.0-rc.1",
#     "@jupyterlab/buildutils": "^3.1.0-rc.1",
#     "chokidar": "^3.4.0",
#     "css-loader": "^5.0.1",
#     "duplicate-package-checker-webpack-plugin": "^3.0.0",
#     "file-loader": "~6.0.0",
#     "fs-extra": "^9.0.1",
#     "glob": "~7.1.6",
#     "handlebars": "^4.5.3",
#     "html-loader": "~1.3.0",
#     "html-webpack-plugin": "^5.0.0-beta.6",
#     "license-webpack-plugin": "^2.3.14",
#     "mini-css-extract-plugin": "~1.3.2",
#     "raw-loader": "~4.0.0",
#     "rimraf": "~3.0.0",
#     "sort-package-json": "~1.44.0",
#     "source-map-loader": "~1.0.2",
#     "style-loader": "~2.0.0",
#     "svg-url-loader": "~6.0.0",
#     "terser-webpack-plugin": "^4.1.0",
#     "url-loader": "~4.1.0",
#     "webpack": "^5.41.1",
#     "webpack-bundle-analyzer": "^3.6.0",
#     "webpack-cli": "^4.1.0",
#     "webpack-merge": "^5.1.2",
#     "whatwg-fetch": "^3.0.0",
#     "worker-loader": "^3.0.2",
#     "yarn-deduplicate": "^2.1.1"
#   },
#   "engines": {
#     "node": ">=12.0.0"
#   },
#   "jupyterlab": {
#     "name": "JupyterLab",
#     "version": "3.1.0rc1",
#     "extensions": {
#       "@jupyterlab/application-extension": "",
#       "@jupyterlab/apputils-extension": "",
#       "@jupyterlab/celltags-extension": "",
#       "@jupyterlab/codemirror-extension": "",
#       "@jupyterlab/completer-extension": "",
#       "@jupyterlab/console-extension": "",
#       "@jupyterlab/csvviewer-extension": "",
#       "@jupyterlab/debugger-extension": "",
#       "@jupyterlab/docmanager-extension": "",
#       "@jupyterlab/docprovider-extension": "",
#       "@jupyterlab/documentsearch-extension": "",
#       "@jupyterlab/extensionmanager-extension": "",
#       "@jupyterlab/filebrowser-extension": "",
#       "@jupyterlab/fileeditor-extension": "",
#       "@jupyterlab/help-extension": "",
#       "@jupyterlab/htmlviewer-extension": "",
#       "@jupyterlab/hub-extension": "",
#       "@jupyterlab/imageviewer-extension": "",
#       "@jupyterlab/inspector-extension": "",
#       "@jupyterlab/launcher-extension": "",
#       "@jupyterlab/logconsole-extension": "",
#       "@jupyterlab/mainmenu-extension": "",
#       "@jupyterlab/markdownviewer-extension": "",
#       "@jupyterlab/mathjax2-extension": "",
#       "@jupyterlab/notebook-extension": "",
#       "@jupyterlab/rendermime-extension": "",
#       "@jupyterlab/running-extension": "",
#       "@jupyterlab/settingeditor-extension": "",
#       "@jupyterlab/shortcuts-extension": "",
#       "@jupyterlab/statusbar-extension": "",
#       "@jupyterlab/terminal-extension": "",
#       "@jupyterlab/theme-dark-extension": "",
#       "@jupyterlab/theme-light-extension": "",
#       "@jupyterlab/toc-extension": "",
#       "@jupyterlab/tooltip-extension": "",
#       "@jupyterlab/translation-extension": "",
#       "@jupyterlab/ui-components-extension": "",
#       "@jupyterlab/vdom-extension": ""
#     },
#     "mimeExtensions": {
#       "@jupyterlab/javascript-extension": "",
#       "@jupyterlab/json-extension": "",
#       "@jupyterlab/pdf-extension": "",
#       "@jupyterlab/vega5-extension": ""
#     },
#     "externalExtensions": {},
#     "buildDir": "./build",
#     "outputDir": "..",
#     "singletonPackages": [
#       "@jupyterlab/application",
#       "@jupyterlab/apputils",
#       "@jupyterlab/codeeditor",
#       "@jupyterlab/codemirror",
#       "@jupyterlab/completer",
#       "@jupyterlab/console",
#       "@jupyterlab/coreutils",
#       "@jupyterlab/debugger",
#       "@jupyterlab/docmanager",
#       "@jupyterlab/docprovider",
#       "@jupyterlab/documentsearch",
#       "@jupyterlab/extensionmanager",
#       "@jupyterlab/filebrowser",
#       "@jupyterlab/fileeditor",
#       "@jupyterlab/imageviewer",
#       "@jupyterlab/inspector",
#       "@jupyterlab/launcher",
#       "@jupyterlab/logconsole",
#       "@jupyterlab/mainmenu",
#       "@jupyterlab/markdownviewer",
#       "@jupyterlab/notebook",
#       "@jupyterlab/rendermime",
#       "@jupyterlab/rendermime-interfaces",
#       "@jupyterlab/services",
#       "@jupyterlab/settingeditor",
#       "@jupyterlab/settingregistry",
#       "@jupyterlab/shared-models",
#       "@jupyterlab/statedb",
#       "@jupyterlab/statusbar",
#       "@jupyterlab/terminal",
#       "@jupyterlab/toc",
#       "@jupyterlab/tooltip",
#       "@jupyterlab/translation",
#       "@jupyterlab/ui-components",
#       "@lumino/algorithm",
#       "@lumino/application",
#       "@lumino/commands",
#       "@lumino/coreutils",
#       "@lumino/disposable",
#       "@lumino/domutils",
#       "@lumino/dragdrop",
#       "@lumino/messaging",
#       "@lumino/properties",
#       "@lumino/signaling",
#       "@lumino/virtualdom",
#       "@lumino/widgets",
#       "react",
#       "react-dom",
#       "yjs"
#     ],
#     "linkedPackages": {},
#     "staticDir": "../static"
#   }
# }
# ```

# %% [markdown]
# ### Jupyter Lab Path
#
# 可以在 命令行 输入 `jupyter lab path` 查看 JupyterLab 的工作路径，比如：
#
# ```bash
# ~ jupyter lab path
# Application directory:   /usr/local/share/jupyter/lab
# User Settings directory: /Users/xxm/.jupyter/lab/user-settings
# Workspaces directory: /Users/xxm/.jupyter/lab/workspaces
# ```
#
# #### Application 目录
#
# ```bash
# ~ cd /usr/local/share/jupyter/lab && ll
# total 8
# drwxr-xr-x   12 xxm  admin   384B  7 20 14:42 extensions
# drwxr-xr-x    5 xxm  admin   160B  7 20 14:59 schemas
# drwxr-xr-x    3 xxm  admin    96B  7 20 14:57 settings
# drwxr-xr-x   16 xxm  admin   512B  7 20 14:59 staging
# drwxr-xr-x  355 xxm  admin    11K  7 20 15:03 static
# -rw-r--r--    1 xxm  admin   2.4K  7 20 14:59 style.js
# drwxr-xr-x    3 xxm  admin    96B  7 16 14:03 themes
# ```
#
# #### Jupyter lab clean
#
# `jupyter lab clean` 会删除 jupyter 应用， `staging` 目录的内容也会被清理掉
#
# #### Jupyter lab build
#
# `jupyter lab build` 会重新 build jupyter 应用，重新拉取 packagejson 中的依赖，然后执行 webpack 等操作，最终重新构建整个 jupyter 应用。
#
# #### Jupyter --core-mode
#
# > Core mode (--core-mode): in this mode JupyterLab will run using the JavaScript assets contained in the installed jupyterlab Python package. In core mode, no extensions are enabled.
#
# `jupyter lab --core-mode` 会使用原始的 python package 来构建应用，因此安装的一些插件、个人配置等内容不会被加载在内，只有核心插件才会被加载，相当于一个 **安全模式** 。

# %% [markdown]
# ### CookieCutter
#
# ```bash
# cookiecutter https://github.com/jupyterlab/mimerender-cookiecutter-ts
# ```
#
# cookiecutter 命令会生成一个 插件 的模板文件，然后可以根据这个模板文件去开发你自己的插件。
