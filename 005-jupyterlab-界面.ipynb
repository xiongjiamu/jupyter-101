# %% [markdown]
# ## JupyterLab 界面
# JupyterLab 界面由由一个包含文档和活动选项卡的主工作区、一个可折叠的左侧边栏和一个菜单栏组成。左侧边栏包含 文件浏览器、正在运行的终端和内核列表、目录、插件管理器。
# ![image.png](attachment:6403dc37-a576-409f-986c-956dbb39ebdb.png)

# %% [markdown]
# ## 菜单栏
# 菜单栏位于窗口顶部。默认菜单是：
# - **文件**：与文件和目录相关的操作
# - **编辑**：与编辑文档和其他活动相关的操作
# - **查看**：更改JupyterLab外观的操作
# - **运行**：用于在不同活动（例如笔记本和代码控制台）中运行代码的操作
# - **内核**：用于管理内核的操作，内核是运行代码的独立过程
# - **标签页**：停靠面板中打开的文档和活动的列表
# - **设置**：常用设置和高级设置编辑器
# - **帮助**：JupyterLab和内核帮助链接的列表

# %% [markdown]
# ## 左侧边栏
# 左侧边栏包含许多常用选项卡，这些选项卡提供以下功能的访问：
# - **文件浏览器**：已保存的笔记本文档和目录的列表
# - **正在运行的内核和终端列表**：具有终止能力的活动内核和终端会话列表
# - **目录**：自动生成目录，使用户方便地查看和浏览文档结构
# - **插件管理器**：安装插件
#
# 通过在“查看”菜单中选择“显示左侧边栏”或单击活动侧边栏选项卡，可以折叠或展开左侧边栏。
#
# JupyterLab 扩展可以向左侧边栏添加额外的面板。

# %% [markdown]
# ## 主要工作区
# JupyterLab 中的主要工作区使您能够将文档（笔记本、文本文件等）和其他活动（终端、代码控制台等）排列到可以调整大小或细分的选项卡面板中。
#
# 将选项卡拖动到选项卡面板的中心以迁移选项卡。 将选项卡拖动到面板的左侧、右侧、顶部或底部，以划分面板。
